# %%
import json
from pprint import pprint
import pandas as pd
import numpy as np

# %%
# Task 0:  Visualization of embedding
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

emb = {}
with open("output.txt") as f:
    for line in f:
        strs = line.split(" ")
        emb[strs[0]] = np.array([float(s) for s in strs[1:]])

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 15}

plt.rc('font', **font)
ax.cla() # clear things for fresh plot

#ax.set_xlim((-1.1, 1.1))
#ax.set_ylim((-1.1, 1.1))


cnt = 0
for key in emb:
    cnt = cnt + 1
    if cnt > 100:
        break
    x = emb[key][0]
    y = emb[key][1]

    ax.plot(x, y, 'o', color='b')
    ax.text(x+0.01, y+0.01, key, color='b')
    
ax.plot(0, 0, 'o', color='r')
#ax.text(x+0.01, y+0.01, "o", color='r')
plt.show()
